# %%
import matplotlib.pyplot as plt

# %%
# 50, 95, 180, 34, 119, 11, 123, 62, 64
seek_sequence = [50, 62, 64, 95, 119, 123, 180, 199, 0, 11, 34]
y_positions = [0, 1, 2, 3, 4, 4, 5, 6, 6, 7, 8]

# %%
plt.figure(figsize=(12,6))
plt.plot(seek_sequence, y_positions, marker='o', linestyle='-', label="C-SCAN Head Movement")
plt.title("C-SCAN")
plt.xlabel("seek sequence")
plt.xticks(seek_sequence)
# Out:
# ([<matplotlib.axis.XTick at 0x291e56c8740>,
# ...
#  [Text(50, 0, '50'),
#   Text(62, 0, '62'),
#   Text(64, 0, '64'),
#   Text(95, 0, '95'),
#   Text(119, 0, '119'),
#   Text(123, 0, '123'),
#   Text(180, 0, '180'),
#   Text(199, 0, '199'),
#   Text(0, 0, '0'),
#   Text(11, 0, '11'),
#   Text(34, 0, '34')])
