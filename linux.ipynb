# %%
b. Working with Files and Directories
mkdir (Make Directory): Creates a new directory.
bash
Copy code
mkdir myfolder
rmdir (Remove Directory): Removes an empty directory.
bash
Copy code
rmdir myfolder
touch: Creates an empty file.
bash
Copy code
touch myfile.txt
rm (Remove): Deletes files.
bash
Copy code
rm myfile.txt
To delete a directory and its contents:
bash
Copy code
rm -r myfolder
c. Viewing File Contents
cat: Displays the content of a file.
bash
Copy code
cat myfile.txt
less: Opens a file for viewing, one screen at a time.
bash
Copy code
less myfile.txt
head: Shows the first few lines of a file.
bash
Copy code
head myfile.txt
tail: Shows the last few lines of a file.
bash
Copy code
tail myfile.txt
d. File Permissions
chmod: Changes file permissions.
bash
Copy code
chmod 755 myfile.txt
ls -l: Shows the permissions of files and directories.
e. Searching for Files
find: Searches for files and directories.
bash
Copy code
find /path -name "filename"
grep: Searches within files.
bash
Copy code
grep "search_term" myfile.txt
4. Working with Processes
ps: Displays currently running processes.
bash
Copy code
ps
top: Displays live processes and resource usage.
bash
Copy code
top
kill: Ends a process by its ID.
bash
Copy code
kill PID

# %%
Basic Usage:
bash
Copy code
echo Hello, Linux!
Output:

Copy code
Hello, Linux!
Common Use Cases:
Displaying Messages:

bash
Copy code
echo "Welcome to Linux!"
Printing Variables:

bash
Copy code
name="Jenith"
echo "Hello, $name"
Output:

Copy code
Hello, Jenith
Redirecting Output to a File:

bash
Copy code
echo "This is a test file." > test.txt
This creates a file test.txt with the content: This is a test file.
Appending to a File:

bash
Copy code
echo "Adding another line." >> test.txt
Escape Characters: Use the -e option for special characters like \n (new line), \t (tab):

bash
Copy code
echo -e "Line1\nLine2"
Output:

Copy code
Line1
Line2
2. cat Command
What It Does:
Concatenates and displays the contents of files.
Basic Usage:
bash
Copy code
cat file.txt
Output:

Displays the content of file.txt.
Use Cases:
Combine Files:
bash
Copy code
cat file1.txt file2.txt > combined.txt
3. head and tail Commands
What They Do:
head: Shows the first lines of a file.
tail: Shows the last lines of a file.
Usage:
Display the first 5 lines of a file:
bash
Copy code
head -n 5 file.txt
Display the last 3 lines of a file:
bash
Copy code
tail -n 3 file.txt
Live Log Monitoring:
Using tail with the -f option:

bash
Copy code
tail -f logfile.txt
Continuously watches a file for updates (useful for logs).
4. touch Command
What It Does:
Creates an empty file.
Usage:
bash
Copy code
touch newfile.txt
Creates a file named newfile.txt if it doesn’t already exist.
5. mkdir and rmdir Commands
What They Do:
mkdir: Creates directories.
rmdir: Removes empty directories.
Usage:
Create a directory:
bash
Copy code
mkdir myfolder
Remove an empty directory:
bash
Copy code
rmdir myfolder
6. rm Command
What It Does:
Deletes files or directories.
Usage:
Remove a file:
bash
Copy code
rm file.txt
Remove a directory with contents:
bash
Copy code
rm -r myfolder
7. cp Command
What It Does:
Copies files or directories.
Usage:
Copy a file:
bash
Copy code
cp file1.txt file2.txt
Copy a directory:
bash
Copy code
cp -r folder1 folder2
8. mv Command
What It Does:
Moves (or renames) files or directories.
Usage:
Rename a file:
bash
Copy code
mv oldname.txt newname.txt
Move a file:
bash
Copy code
mv file.txt /path/to/destination/
9. find Command
What It Does:
Searches for files and directories.
Usage:
Find files by name:
bash
Copy code
find /path -name "file.txt"
10. grep Command
What It Does:
Searches for a specific text within files.
Usage:
Search for a word in a file:
bash
Copy code
grep "Linux" file.txt
Search recursively in all files of a directory:
bash
Copy code
grep -r "word" /path
Quick Recap Table
Command	Purpose	Example
echo	Print text or variables	echo "Hello, Linux!"
cat	Display file contents	cat file.txt
head	Show first lines of file	head -n 5 file.txt
tail	Show last lines of file	tail -n 3 file.txt
touch	Create empty file	touch newfile.txt
mkdir	Create directory	mkdir myfolder
rmdir	Remove empty directory	rmdir myfolder
rm	Remove files/directories	rm -r myfolder
cp	Copy files/directories	cp file1.txt file2.txt
mv	Move or rename files	mv oldname.txt newname.txt
find	Search files/directories	find /path -name "file.txt"
grep	Search within files	grep "text" file.txt
Would you like me to provide examples of using these commands together in a small project?

# %%
Great! Learning Linux commands from the basics is a rewarding process. Let’s start with the foundational commands and build up gradually. Here’s a step-by-step guide:

1. Understanding the Linux Terminal
The terminal is where you type commands to interact with the Linux operating system.
You can open it in most Linux distributions by pressing Ctrl + Alt + T.
2. Basic Structure of Commands
A Linux command typically follows this format:

bash
Copy code
command [options] [arguments]
command: The action you want to perform (e.g., ls, cd).
options: Modify the behavior of the command (e.g., -l, -a).
arguments: The target of the command (e.g., a file or directory name).
3. Basic Commands
a. Navigating the File System
